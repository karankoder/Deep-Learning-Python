# %%
import pandas as pd 
df_meta=pd.read_csv('GRF_metadata.csv')
df_meta=df_meta[df_meta['TRAIN']==1]
df_meta = df_meta.iloc[:,:17]
df_meta
# Out:
#       SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  SEX  AGE  \
# 3              2   888812549          HC                   HC    1   51
# 4              2   888812550          HC                   HC    1   51
# 5              2   888812548          HC                   HC    1   51
# 6              3       19709          HC                   HC    1   26
# 7              3       19710          HC                   HC    1   26
# ...          ...         ...         ...                  ...  ...  ...
# 8958        2390       15451           A                  A_F    1   47
# 8959        2391       15442           A                  A_L    1   55
# 8960        2391       15501           A                  A_L    1   55
# 8961        2391       15622           A                  A_L    1   56
# 8962        2391       15703           A                  A_L    1   56
#
#       HEIGHT  BODY_WEIGHT  BODY_MASS  SHOE_SIZE  AFFECTED_SIDE  \
# ...

# %%
df_train=pd.read_csv('GRF_F_V_RAW_right.csv')
df_train
# Out:
#        SUBJECT_ID  SESSION_ID  TRIAL_ID  F_V_RAW_1   F_V_RAW_2   F_V_RAW_3  \
# 0             510         413         1  25.012121   71.665275  117.186824
# 1             510         413         2  25.016710   63.569407  101.153295
# 2             510         413         3  25.026936   60.096013  101.144933
# 3             510         413         4  25.021733   61.788997  105.290472
# 4             510         413         6  25.025240   72.749964  123.243514
# ...           ...         ...       ...        ...         ...         ...
# 75727          93   999910375         6  25.073018  125.523771  482.843846
# 75728          93   999910375         7  25.017423  138.167192  426.536328
# 75729          93   999910375         9  25.048961  140.151932  461.711734
# 75730          93   999910375        10  25.113446  163.863373  471.133905
# 75731          93   999910375        11  25.014171  105.003553  310.971194
#
# ...

# %%
df_final= pd.merge(df_meta, df_train, on='SESSION_ID')
df_final
df_final.to_csv('output.csv', index=False)
